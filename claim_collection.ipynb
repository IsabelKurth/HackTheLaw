# %%
# ==============================================================================
# STEP 1: SETUP AND INITIALIZATION FOR VERTEX AI
# ==============================================================================
import vertexai
from vertexai.generative_models import GenerativeModel, GenerationConfig, HarmCategory, HarmBlockThreshold
import pandas as pd
import os
import json
from tqdm.notebook import tqdm
import time

# --- Configuration for Vertex AI Workbench ---
# Using the project ID identified from the previous error.
PROJECT_ID = "hack-thelaw25cam-586"
LOCATION = "us-central1" 

# Initialize the Vertex AI SDK. It will use the credentials of your Workbench instance.
vertexai.init(project=PROJECT_ID, location=LOCATION)
print(f"Vertex AI initialized for project: {PROJECT_ID}")

# --- Model Configuration ---
generation_config = GenerationConfig(
    temperature=0.2,
    top_p=0.95,
    top_k=40,
    max_output_tokens=8192,
)

safety_settings = {
    HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
}

# --- CORRECTED MODEL NAME ---
# Using the official public name for Gemini 1.5 Flash.
model = GenerativeModel(
    "gemini-2.0-flash-lite-001",
    generation_config=generation_config,
    safety_settings=safety_settings
)
print("Setup complete. Gemini model via Vertex AI is ready.")


# ==============================================================================
# STEP 2: FUNCTION TO ANALYZE TEXT WITH ENHANCED CONTEXT EXTRACTION
# ==============================================================================
def analyze_decision_text(decision_text: str) -> list:
    """
    Sends decision text to Gemini and asks it to extract legal arguments with rich context
    optimized for similarity matching.
    """
    # --- UPDATED: New enhanced prompt for richer context ---
    prompt = [
        "You are an expert legal analyst specializing in international arbitration. Your task is to read the following legal decision text and identify the distinct arguments made by the Claimant (or Petitioner/Investor) and the Respondent (or Defendant/State).",
        "For each distinct argument you identify, you must provide a structured JSON object with the following information:",
        "1. `argument_summary`: A concise, one-sentence summary of the argument.",
        "2. `party`: The party that made the argument ('Claimant' or 'Respondent').",
        "3. `legal_basis`: The specific treaty articles (e.g., 'DR-CAFTA Art. 10.16.1'), legal principles (e.g., 'effet utile', 'VCLT Art. 31'), or case law cited as the foundation for the argument.",
        "4. `key_keywords`: A JSON list of important legal or factual keywords related to the argument (e.g., ['reflective loss', 'fork-in-the-road', 'waiver requirement', 'NAFTA']).",
        "5. `court_followed`: Whether the tribunal/court followed the argument ('Yes', 'No', or 'Partial/Deferred').",
        "6. `tribunal_reasoning`: A concise summary of WHY the tribunal agreed or disagreed with this specific argument. If the reasoning is not explicitly stated, use 'N/A'.",

        "Provide your output as a valid JSON array of objects only. Do not include any other text, explanation, or markdown formatting. Each object must have these exact keys: `argument_summary`, `party`, `legal_basis`, `key_keywords`, `court_followed`, `tribunal_reasoning`.",
        "Example output format:",
        """
[
  {
    "argument_summary": "The Respondent argued that claims for reflective loss must be brought under Article 10.16.1(b) to avoid rendering that provision meaningless.",
    "party": "Respondent",
    "legal_basis": "DR-CAFTA Art. 10.16.1(b), Principle of 'effet utile', VCLT Art. 31",
    "key_keywords": ["reflective loss", "derivative claim", "effet utile", "shareholder claims", "treaty interpretation"],
    "court_followed": "No",
    "tribunal_reasoning": "The majority found that Article 10.16.1(b) was not rendered useless because it offers a different utility, such as recovering 100% of an enterprise's losses, which is distinct from a shareholder's specific loss claim."
  }
]
        """,
        "Here is the legal decision text:",
        "---",
        decision_text
    ]

    try:
        response = model.generate_content(prompt)
        # Clean the response to ensure it's valid JSON
        cleaned_response_text = response.text.strip().replace("```json", "").replace("```", "")
        if not cleaned_response_text:
            return [] # Return empty list if the model gives an empty response
        extracted_arguments = json.loads(cleaned_response_text)
        if isinstance(extracted_arguments, list):
            return  extracted_arguments
        else:
            print(f"Warning: API returned a non-list object: {type(extracted_arguments)}")
            return []
    except (json.JSONDecodeError, ValueError) as e:
        print(f"Error parsing JSON from API response: {e}")
        raw_text = getattr(response, 'text', 'Response blocked or empty.')
        print(f"Raw response was: {raw_text}")
        return []
    except Exception as e:
        print(f"An unexpected error occurred during API call: {e}")
        return []

# ==============================================================================
# STEP 3: MAIN SCRIPT TO PROCESS FILES AND BUILD DATABASE
# ==============================================================================

# Using the folder path you provided in your last script.
FOLDER_PATH = 'jus_mundi_hackathon_data/cases/'
all_extracted_arguments = []

if not os.path.exists(FOLDER_PATH):
    print(f"Error: Folder not found at '{FOLDER_PATH}'. Please check the path.")
else:
    json_files = sorted([f for f in os.listdir(FOLDER_PATH) if f.endswith('.json')])
    
    # --- TESTING LIMIT ---
    # Processing only the first 10 files as requested.
    # To run on all ~600 files, REMOVE the slicing '[:10]' from the line below.
    files_to_process = json_files[100:300]
    print(f"Starting processing for {len(files_to_process)} test files...")

    for filename in tqdm(files_to_process, desc="Processing Files"):
        file_path = os.path.join(FOLDER_PATH, filename)
        
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                case_data = json.load(f)

            case_identifier = case_data.get("Identifier", "Unknown_ID")
            case_title = case_data.get("Title", "Unknown_Title")
            
            print(f"\nProcessing Case: {case_title} | ID: {case_identifier}")

            # Iterate through all decisions and opinions in the case
            for document in case_data.get("Decisions", []):
                # We can process the main decision and its opinions in the same sub-loop
                all_docs_to_analyze = [document] + document.get("Opinions", [])
                
                for doc in all_docs_to_analyze:
                  if doc and doc.get("Content"):
                      doc_text = doc["Content"]
                      doc_title = doc.get("Title", "N/A")
                      doc_type = doc.get("Type", "N/A")
                      
                      # A small delay to avoid hitting API rate limits, especially on long runs.
                      time.sleep(0.1)

                      print(f"  - Analyzing: '{doc_title}' ({doc_type})")
                      arguments = analyze_decision_text(doc_text)
                      
                      for arg in arguments:
                          # Add all relevant metadata to each extracted argument object
                          arg['case_identifier'] = case_identifier
                          arg['case_title'] = case_title
                          arg['document_title'] = doc_title
                          arg['document_type'] = doc_type
                          all_extracted_arguments.append(arg)
                          
        except Exception as e:
            print(f"Could not process file {filename}. Error: {e}")

# ==============================================================================
# STEP 4: CREATE AND SAVE THE DATABASE
# ==============================================================================
print("\nProcessing complete. Creating DataFrame from extracted arguments.")
df = pd.DataFrame(all_extracted_arguments)

if not df.empty:
    # --- UPDATED: Column order for rich context ---
    column_order = [
        'case_identifier', 
        'case_title', 
        'document_title', 
        'document_type', 
        'party', 
        'argument_summary', 
        'legal_basis',
        'key_keywords',
        'court_followed', 
        'tribunal_reasoning'
    ]
    # Ensure all columns exist before trying to reorder, filling missing ones with None
    for col in column_order:
        if col not in df.columns:
            df[col] = None 
            
    df = df[column_order]
    
    # Using a new filename to reflect the richer content
    output_filename = 'legal_arguments_database.csv'
    df.to_csv(output_filename, index=False, encoding='utf-8-sig')

    print(f"\nDatabase created successfully with {len(df)} arguments.")
    print(f"Saved to '{output_filename}'")
    
    # Display the first 15 rows of the new database
    display(df.head(15))
else:
    print("No arguments were extracted. The DataFrame is empty.")
# Out:
# Vertex AI initialized for project: hack-thelaw25cam-586
# Setup complete. Gemini model via Vertex AI is ready.
# Starting processing for 200 test files...
# Processing Files:   0%|          | 0/200 [00:00<?, ?it/s]
# Processing Case: Bacilio Amorrortu v. Peru (II) | ID:
#   - Analyzing: 'Procedural Order No. 2 (Decision on Bifurcation)' (Bifurcation)
#
# Processing Case: Itisaluna Iraq and others v. Iraq | ID: IDS-796
#   - Analyzing: 'Award' (Award (Final))
#   - Analyzing: 'Dissenting Opinion of Wolfgang Peter (Incorporated in Final Award)' (Dissenting Opinion)
#
# Processing Case: Watkins Holdings v. Spain | ID: IDS-673
#   - Analyzing: 'Award' (Award (Final))
#   - Analyzing: 'Dissent on Liability and Quantum of Prof. Dr. Hélène Ruiz Fabri' (Dissenting Opinion)
#   - Analyzing: 'Decision on Spain's Request for Rectification of the Award' (Supplementary)
#
# Processing Case: WCV and Channel Crossings v. Czech Republic | ID: IDS-694
#   - Analyzing: 'Final Award' (Award (Final))
#
# Processing Case: A11Y v. Czech Republic | ID: IDS-578
#   - Analyzing: 'Decision on Bifurcation' (Bifurcation)
#   - Analyzing: 'Decision on Jurisdiction' (Jurisdiction)
#   - Analyzing: 'Award' (Award (Final))
#
# Processing Case: Anglo American v. Venezuela | ID: IDS-605
#   - Analyzing: 'Award' (Award (Final))
#   - Analyzing: 'Dissenting Opinion of Prof. Dr. Guido Santiago Tawil' (Dissenting Opinion)
#
# Processing Case: Windstream Energy v. Canada (II) | ID:
#   - Analyzing: 'Procedural Order No. 2 (Decision on Bifurcation)' (Bifurcation)
#
# Processing Case: Ansung Housing v. China | ID: IDS-602
#   - Analyzing: 'Award' (Award (Final))
#
# Processing Case: Benabderrahmane v. Qatar | ID:
#   - Analyzing: 'Procedural Order No. 1 (Decision on Applicable Arbitration Rules)' (Preliminary Issues)
#   - Analyzing: 'Procedural Order No. 5 (Request for Provisional Measures)' (Interim & Provisional Measures)
#   - Analyzing: 'Procedural Order No. 6 (Request for Bifurcation)' (Bifurcation)
#   - Analyzing: 'Concurring Opinion of Makhdoom Ali Khan' (Concurring Opinion)
#   - Analyzing: 'Procedural Order No. 7 (Request for Additional Provisional Measures)' (Interim & Provisional Measures)
#
# Processing Case: Aven and others v. Costa Rica | ID: IDS-571
#   - Analyzing: 'Final Award' (Award (Final))
#
# Processing Case: Kazmin v. Latvia | ID: IDS-792
#   - Analyzing: 'Award' (Award (Final))
#
# Processing Case: Ballantine v. Dominican Republic | ID: IDS-687
#   - Analyzing: 'Procedural Order No. 2 (Bifurcation)' (Bifurcation)
#   - Analyzing: 'Final Award' (Award (Final))
#   - Analyzing: 'Partial Dissent by Prof. Vinuesa on Costs' (Dissenting Opinion)
#   - Analyzing: 'Partial Dissent of Ms. Cheek on Jurisdiction' (Dissenting Opinion)
#
# Processing Case: Beijing Urban Construction v. Yemen | ID: IDS-573
#   - Analyzing: 'Decision on Jurisdiction' (Jurisdiction)
#
# Processing Case: Besserglik v. Mozambique | ID: IDS-606
#   - Analyzing: 'Award' (Award (Final))
#
# Processing Case: Blusun v. Italy | ID: IDS-575
#   - Analyzing: 'Award' (Award (Final))
#   - Analyzing: 'Decision on Annulment' (Annulment)
#
# Processing Case: Casinos Austria v. Argentina | ID: IDS-603
#   - Analyzing: 'Decision on Jurisdiction' (Jurisdiction)
#   - Analyzing: 'Dissenting Opinion on Respondent’s Second Preliminary Objection and Declaration of Dissent concerning its First and Third Preliminary Objections of Arbitrator Santiago Torres Bernárdez' (Dissenting Opinion)
#   - Analyzing: 'Award' (Award (Final))
#   - Analyzing: 'Dissenting Opinion of Dr. Santiago Torres Bernárdez' (Dissenting Opinion)
#
# Processing Case: CEAC v. Montenegro | ID: IDS-597
#   - Analyzing: 'Award' (Award (Final))
#   - Analyzing: 'Separate Opinion of William W. Park' (Dissenting Opinion)
#   - Analyzing: 'Decision on Annulment' (Annulment)
#
# Processing Case: Corona Materials v. Dominican Republic | ID: IDS-601
#   - Analyzing: 'Award on the Respondent's Expedited Preliminary Objections in Accordance with Article 10.20.5 of the DR-CAFTA' (Award (Final))
#
# Processing Case: Cyprus Popular Bank v. Greece | ID: IDS-587
#   - Analyzing: 'Decision on Jurisdiction and Liability' (Liability)
#   - Analyzing: 'Award' (Award (Final))
#   - Analyzing: 'Decision on Annulment' (Annulment)
#
# Processing Case: Bear Creek Mining v. Peru | ID: IDS-580
#   - Analyzing: 'Procedural Order No. 2 (Regarding Claimant’s Request for Provisional Measures)' (Interim & Provisional Measures)
#   - Analyzing: 'Award' (Award (Final))
#   - Analyzing: 'Partial Dissenting Opinion of Professor Philippe Sands QC' (Dissenting Opinion)
#
# Processing Case: EuroGas v. Slovakia | ID: IDS-594
#   - Analyzing: 'Procedural Order No. 3 (Decision on the Parties' Request for Provisional Measures)' (Interim & Provisional Measures)
#   - Analyzing: 'Award of the Tribunal' (Award (Final))
#   - Analyzing: 'Dissenting Opinion by Arbitrator Emmanuel Gaillard' (Dissenting Opinion)
#
# Processing Case: Flemingo DutyFree v. Poland | ID: IDS-771
#   - Analyzing: 'Award' (Award (Final))
#
# Processing Case: Lidercón v. Peru | ID: IDS-795
#   - Analyzing: 'Award' (Award (Final))
#
# Processing Case: Infinito Gold v. Costa Rica | ID: IDS-595
#   - Analyzing: 'Decision on Jurisdiction' (Jurisdiction)
#   - Analyzing: 'Award' (Award (Final))
#   - Analyzing: 'Separate Opinion on Jurisdiction and on the Merits of Professor Brigitte Stern' (Opinion)
#
# Processing Case: InfraRed v. Spain | ID: IDS-574
#   - Analyzing: 'Decision on the Continuation of the Stay of Enforcement of the Award' (Stay of Enforcement)
#   - Analyzing: 'Decision on Annulment' (Annulment)
#
# Processing Case: Krederi v. Ukraine | ID: IDS-576
#   - Analyzing: 'Award' (Award (Final))
#
# Processing Case: LDA v. India | ID: IDS-600
#   - Analyzing: 'Decision on Jurisdiction' (Jurisdiction)
#   - Analyzing: 'Award' (Award (Final))
#
# Processing Case: Masdar Solar v. Spain | ID: IDS-593
#   - Analyzing: 'Award' (Award (Final))
#   - Analyzing: 'Decision on the Respondent's Application to Stay Enforcement of the Award' (Stay of Enforcement)
#
# Processing Case: Mera Investment v. Serbia | ID: IDS-790
#   - Analyzing: 'Decision on Jurisdiction' (Jurisdiction)
#
# Processing Case: RENERGY v. Spain | ID: IDS-590
#   - Analyzing: 'Decision on Annulment' (Annulment)
# Error parsing JSON from API response: Expecting ',' delimiter: line 54 column 84 (char 4349)
# Raw response was: ```json
# [
#   {
#     "argument_summary": "Spain argued that the Tribunal lacked jurisdiction because the dispute was an intra-EU matter, and Article 26 ECT was inapplicable.",
#     "party": "Respondent",
#     "legal_basis": "ICSID Convention Art. 25, ECT Art. 26, CJEU case law (*Achmea*, *Komstroy*)",
#     "key_keywords": ["intra-EU", "jurisdiction", "Achmea", "Komstroy", "Article 26 ECT", "REIO"],
#     "court_followed": "No",
#     "tribunal_reasoning": "The Tribunal found its jurisdiction based on the ECT and ICSID Convention, not EU law. It reasoned that even if EU law applied, the *Achmea* and *Komstroy* judgments did not invalidate the ECT's arbitration clause from an international law perspective."
#   },
#   {
#     "argument_summary": "Spain contended that the Tribunal manifestly exceeded its powers by disregarding EU law, which should have been applied to assess the merits of the case, particularly regarding State aid and investor expectations.",
#     "party": "Respondent",
#     "legal_basis": "TFEU, RD 661/2007, EU State Aid regulations, ECT Art. 16(2)",
#     "key_keywords": ["State aid", "legitimate expectations", "EU law", "RD 661/2007", "Article 16(2) ECT"],
#     "court_followed": "No",
#     "tribunal_reasoning": "The Tribunal considered EU law but found Article 16(2) ECT precluded its application because the ECT was more favorable to the investor. The Tribunal also found that even if EU State Aid rules were applicable, Spain's failure to notify RF1 to the EC did not preclude the Claimant from holding legitimate expectations."
#   },
#   {
#     "argument_summary": "Spain argued that the Award should be annulled because it failed to state reasons, particularly regarding the applicability of EU law to jurisdiction and the merits of the dispute.",
#     "party": "Respondent",
#     "legal_basis": "ICSID Convention Art. 52(1)(e)",
#     "key_keywords": ["failure to state reasons", "EU law", "jurisdiction", "merits", "Achmea", "Komstroy"],
#     "court_followed": "No",
#     "tribunal_reasoning": "The Tribunal provided reasons for its jurisdictional findings, including why it did not need to apply EU law. The Tribunal also provided a reasoned analysis of the merits, including the application of Article 16(2) ECT and the implications of EU law."
#   },
#   {
#     "argument_summary": "Renergy argued that the Tribunal correctly asserted jurisdiction under the ECT and did not need to apply EU law.",
#     "party": "Claimant",
#     "legal_basis": "ECT Art. 26, ICSID Convention Art. 25",
#     "key_keywords": ["jurisdiction", "ECT", "EU law", "Achmea", "Komstroy"],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Committee agreed with the Tribunal's reasoning, finding that the Tribunal's jurisdictional analysis was tenable and that the *Achmea* and *Komstroy* judgments did not invalidate the ECT's arbitration clause from an international law perspective."
#   },
#   {
#     "argument_summary": "Renergy contended that the Tribunal correctly applied the proper law and did not err in not applying EU State Aid Rules to the merits of the dispute.",
#     "party": "Claimant",
#     "legal_basis": "ECT Art. 16(2), VCLT Art. 27, ARSIWA",
#     "key_keywords": ["State Aid Rules", "merits", "Article 16(2) ECT", "VCLT", "ARSIWA"],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Committee agreed that the Tribunal did not err in its application of the law. The Tribunal found that Article 16(2) ECT precluded the application of EU State Aid Rules."
#   },
#   {
#     "argument_summary": "Renergy argued that the Tribunal provided sufficient reasons for its findings and that Spain's disagreement with the Award's reasoning was not a basis for annulment.",
#     "party": "Claimant",
#     "legal_basis": "ICSID Convention Art. 52(1)(e)",
#     "key_keywords": ["failure to state reasons", "reasoning", "merits", "jurisdiction"],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Committee agreed that the Tribunal provided sufficient reasons for its findings and that Spain's disagreement with the Award's reasoning was not a basis for annulment."
#   },
#   {
#     "argument_summary": "Renergy requested that the Committee dismiss Spain's application for annulment and order Spain to pay all costs, including legal fees and interest.",
#     "party": "Claimant",
#     "legal_basis": "ICSID Convention Art. 61(2), ICSID Arbitration Rule 47(1)(j), "costs follow the event" principle",
#     "key_keywords": ["costs", "costs follow the event", "legal fees", "interest"],
#     "court_followed": "Partial/Deferred",
#     "tribunal_reasoning": "The Committee dismissed Spain's application for annulment. The Committee ordered Spain to bear its own legal costs and expenses, reimburse Renergy 85% of its costs, and bear all costs of the proceedings, including the Committee's fees and expenses and ICSID's costs. The Committee deferred the decision on the interest rate."
#   }
# ]
# ```
#
# Processing Case: RWE Innogy v. Spain | ID: IDS-586
#   - Analyzing: 'Decision on Jurisdiction, Liability, and Certain Issues of Quantum' (Liability)
#   - Analyzing: 'Award' (Award (Final))
#   - Analyzing: 'Separate Opinion of Mr. Judd L. Kessler' (Opinion)
#
# Processing Case: MetLife v. Argentina | ID: IDS-803
#   - Analyzing: 'Procedural Order No. 2 Decision on Bifurcation' (Bifurcation)
#
# Processing Case: Sodexo Pass v. Hungary | ID: IDS-599
#   - Analyzing: 'Award (Excerpts)' (Award (Final))
#   - Analyzing: 'Separate and Dissenting Opinion of J. Christopher Thomas (Excerpts)' (Dissenting Opinion)
#   - Analyzing: 'Decision on the Request for the Continued Stay of Enforcement of the Award' (Stay of Enforcement)
#   - Analyzing: 'Decision on Annulment (Excerpts)' (Annulment)
#
# Processing Case: Tallinn v. Estonia | ID: IDS-598
#   - Analyzing: 'Procedural Order No. 2 (Decision on Respondent’s Request for Bifurcation and on the Timetable for the Arbitration)' (Bifurcation)
#   - Analyzing: 'Decision on Respondent's Application for Provisional Measures' (Interim & Provisional Measures)
# Error parsing JSON from API response: Expecting ',' delimiter: line 110 column 33 (char 7155)
# Raw response was: ```json
# [
#   {
#     "argument_summary": "Respondent argued that Claimants have been waging an aggressive, one-sided media campaign against the Estonian Government since the initiation of this arbitration.",
#     "party": "Respondent",
#     "legal_basis": "N/A",
#     "key_keywords": ["media campaign", "one-sided", "publicity", "due process", "trial by media"],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The tribunal acknowledged the existence of a media campaign, though it did not characterize it as 'aggressive' or 'one-sided'."
#   },
#   {
#     "argument_summary": "Respondent argued that the Application satisfies the requirements of Article 47 of the ICSID Convention for provisional measures.",
#     "party": "Respondent",
#     "legal_basis": "ICSID Convention Art. 47, Menzies v. Senegal",
#     "key_keywords": ["prima facie jurisdiction", "right susceptible of protection", "necessity", "urgency", "proportionality"],
#     "court_followed": "Partial/Deferred",
#     "tribunal_reasoning": "The tribunal agreed that the requirements for provisional measures were met, but it framed the specific measures differently than Respondent requested."
#   },
#   {
#     "argument_summary": "Respondent argued that the Tribunal has prima facie jurisdiction.",
#     "party": "Respondent",
#     "legal_basis": "Pey Casado v. Chile, Occidental Petroleum Corporation and Occidental Exploration and Production Company v. Republic of Ecuador",
#     "key_keywords": ["prima facie jurisdiction", "consent", "BIT"],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The tribunal agreed that it had prima facie jurisdiction based on the consent between the parties."
#   },
#   {
#     "argument_summary": "Respondent argued that it seeks protection of its vital procedural rights, including the right to due process and the right to the non-aggravation of the dispute.",
#     "party": "Respondent",
#     "legal_basis": "ICSID Convention Art. 47, Burlington Resources Inc. v. Republic of Ecuador, Plama Consortium Limited v. Republic of Bulgaria, Quiborax S.A., Non Metallic Minerals S.A. and Allan Fosk Kaplún v. Plurinational State of Bolivia",
#     "key_keywords": ["due process", "non-aggravation", "procedural rights", "trial in the media"],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The tribunal agreed that procedural rights were susceptible of protection by provisional measures."
#   },
#   {
#     "argument_summary": "Respondent argued that the necessity requirement for provisional measures is met because publication of the Excerpts and other Arbitration Documents will put enormous media pressure on the Estonian government, lead to a discussion in the media of the specific issues to be decided in the arbitration, and result in the misuse of such arguments to fuel a political debate in Estonia.",
#     "party": "Respondent",
#     "legal_basis": "Biwater Gauff v. Tanzania, Abaclat v. Argentina",
#     "key_keywords": ["necessity", "media pressure", "political debate", "exacerbation of dispute"],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The tribunal agreed that the publication of the Extract would inevitably harm the parties' respective rights in the dispute."
#   },
#   {
#     "argument_summary": "Respondent argued that the measures sought in the Application are urgent.",
#     "party": "Respondent",
#     "legal_basis": "N/A",
#     "key_keywords": ["urgency", "irreparable harm", "due process"],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The tribunal agreed that the urgency requirement was satisfied."
#   },
#   {
#     "argument_summary": "Claimants argued that they have not waged, are not waging and have no intention of waging an aggressive media campaign.",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": ["media campaign", "publicity", "extract", "shareholders"],
#     "court_followed": "No",
#     "tribunal_reasoning": "The tribunal acknowledged the existence of a media campaign, though it did not characterize it as 'aggressive' or 'one-sided'."
#   },
#   {
#     "argument_summary": "Claimants argued that they are proposing nothing more than to post online an extract from their Memorial.",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": ["extract", "Memorial", "shareholders", "customers"],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The tribunal acknowledged the limited scope of the proposed publication."
#   },
#   {
#     "argument_summary": "Claimants argued that the Application fails to meet the requirements of Article 47 of the ICSID Convention.",
#     "party": "Claimant",
#     "legal_basis": "ICSID Convention Art. 47, Quiborax et al. v. Bolivia, Burlington v. Ecuador",
#     "key_keywords": ["prima facie jurisdiction", "prima facie case", "necessity", "urgency", "proportionality"],
#     "court_followed": "No",
#     "tribunal_reasoning": "The tribunal found that the requirements for provisional measures were met."
#   },
#   {
#     "argument_summary": "Claimants argued that there exists no duty of confidentiality in ICSID arbitration.",
#     "party": "Claimant",
#     "legal_basis": "World Duty Free, Biwater",
#     "key_keywords": ["confidentiality", "transparency", "publication"],
#     "court_followed": "Partial/Deferred",
#     "tribunal_reasoning": "The tribunal agreed that there is no general duty of confidentiality, but also no general right to disclose."
#   },
#   {
#     "argument_summary": "Claimants argued that the cases Respondent relies upon in support of its Application, namely Biwater, Lao Holdings, and Abaclat, must be distinguished from the present case.",
#     "party": "Claimant",
#     "legal_basis": "Biwater, Lao Holdings, Abaclat",
#     "key_keywords": ["Biwater", "Lao Holdings", "Abaclat", "distinguishable"],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The tribunal considered the cases but did not fully accept the Claimants' arguments for distinguishing them."
#   },
#   {
#     "argument_summary": "Claimants argued that Respondent has failed to establish the existence of a right susceptible of protection and any threat to this right that the proposed publication might pose.",
#     "party": "Claimant",
#     "legal_basis": "Burlington v. Ecuador, Plama v. Bulgaria, Quiborax v. Bolivia",
#     "key_keywords": ["right susceptible of protection", "procedural rights", "underlying dispute"],
#     "court_followed": "No",
#     "tribunal_reasoning": "The tribunal disagreed, finding that the procedural rights were at risk."
#   },
#   {
#     "argument_summary": "Claimants argued that Respondent has not proven the necessity of the requested measures.",
#     "party": "Claimant",
#     "legal_basis": "CEMEX Caracas Investments B.V. and CEMEX Caracas II Investments B.V. v. Bolivarian Republic of Venezuela, Valle Verde Sociedad Financiera S.L. v. Bolivarian Republic of Venezuela",
#     "key_keywords": ["necessity", "serious and irreparable harm", "media coverage"],
#     "court_followed": "No",
#     "tribunal_reasoning": "The tribunal found that the harm was likely to occur."
#   },
#   {
#     "argument_summary": "Claimants argued that the Application does not address the issue of proportionality.",
#     "party": "Claimant",
#     "legal_basis": "Gary Born, "International Commercial Arbitration"",
#     "key_keywords": ["proportionality", "balance of inconvenience", "transparency"],
#     "court_followed": "No",
#     "tribunal_reasoning": "The tribunal considered the proportionality and found the measures to be proportionate."
#   }
# ]
# ```
#   - Analyzing: 'Decision on the Application for Leave to Intervene as a Non-Disputing Party Submitted by the European Commission' (Other)
#   - Analyzing: 'Award' (Award (Final))
#   - Analyzing: 'Dissent of Sir David A.R. Williams KNZM, QC.' (Dissenting Opinion)
#
# Processing Case: Unión Fenosa Gas v. Egypt | ID: IDS-567
#   - Analyzing: 'Award' (Award (Final))
#   - Analyzing: 'Dissenting Opinion of Arbitrator Mark Clodfelter' (Dissenting Opinion)
#   - Analyzing: 'Decision to Terminate the Stay of Enforcement of the Award' (Stay of Enforcement)
#
# Processing Case: ABG v. Mexico | ID:
#   - Analyzing: 'Procedural Order No. 3 (Bifurcation)' (Bifurcation)
#
# Processing Case: WNC v. Czech Republic | ID: IDS-667
#   - Analyzing: 'Award' (Award (Final))
#
# Processing Case: Rizzani de Eccher and others v. Kuwait | ID: IDS-794
#   - Analyzing: 'Decision on Provisional Measures' (Interim & Provisional Measures)
#
# Processing Case: Achmea v. Slovakia (II) | ID: IDS-519
#   - Analyzing: 'Award on Jurisdiction and Admissibility' (Award (Final))
#
# Processing Case: Suffolk and others v. Portugal | ID:
#   - Analyzing: 'Procedural Order No. 3 (Respondent’s Request for Bifurcation)' (Bifurcation)
#
# Processing Case: Ershova and Jeršov v. Bulgaria | ID:
#   - Analyzing: 'Procedural Order No. 1 (Applicable ICSID Arbitration Rules)' (Preliminary Issues)
#   - Analyzing: 'Decision on the Respondent’s Preliminary Objection Under Art. 41(5) of the ICSID Arbitration Rules' (ICSID Arbitration Rule 41(5))
#
# Processing Case: Bank of Nova Scotia v.  Peru | ID:
#   - Analyzing: 'Decision on Respondent’s Rule 41 Application' (ICSID Arbitration Rule 41(5))
#
# Processing Case: Alghanim v. Jordan | ID: IDS-527
#   - Analyzing: 'Order on Application for the Grant of Provisional Measures' (Interim & Provisional Measures)
#   - Analyzing: 'Award' (Award (Final))
#   - Analyzing: 'Separate Opinion of Yves Fortier' (Concurring Opinion)
#
# Processing Case: Almås v. Poland | ID: IDS-663
#   - Analyzing: 'Award' (Award (Final))
#
# Processing Case: Infrastructure Services (Antin) v. Spain | ID: IDS-556
#   - Analyzing: 'Decision on the Continuation of the Provisional Stay of Enforcement of the Award' (Stay of Enforcement)
#
# Processing Case: Spence International Investments et al. v. Costa Rica | ID: IDS-562
#   - Analyzing: 'Interim Award' (Award (Interim))
#   - Analyzing: 'Interim Award (Corrected)' (Award (Interim))
#
# Processing Case: Kim and others v. Uzbekistan | ID: IDS-533
#   - Analyzing: 'Decision on Jurisdiction' (Jurisdiction)
#
# Processing Case: Caratube v. Kazakhstan (II) | ID: IDS-539
#   - Analyzing: 'Decision on the Proposal for Disqualification of Bruno Boesch' (Arbitrator & Judge Challenge)
#   - Analyzing: 'Decision on the Claimants' Request for Provisional Measures' (Interim & Provisional Measures)
#   - Analyzing: 'Award' (Award (Final))
# Error parsing JSON from API response: Expecting property name enclosed in double quotes: line 664 column 87 (char 30157)
# Raw response was: ```json
# [
#   {
#     "argument_summary": "Claimant is a Kazakh-incorporated company with foreign ownership and its majority shareholder, a US national, and the term \"Claimants\" jointly refers to CIOC and Mr. Devincci Hourani only up to the decision on jurisdiction. Thereafter, it will only refer to CIOC.",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "Caratube International Oil Company LLP",
#       "CIOC",
#       "Devincci Salah Hourani",
#       "US national"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this definition of the Claimants."
#   },
#   {
#     "argument_summary": "The Respondent is the Republic of Kazakhstan.",
#     "party": "Respondent",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "Republic of Kazakhstan",
#       "Kazakhstan"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this definition of the Respondent."
#   },
#   {
#     "argument_summary": "The Ministry of Energy and Mineral Resources of the Republic of Kazakhstan (MEMR) negotiated, executed, and performed the contract underlying the dispute on behalf of the Respondent.",
#     "party": "Respondent",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "MEMR",
#       "Ministry of Energy and Mineral Resources of the Republic of Kazakhstan"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this definition of the MEMR."
#   },
#   {
#     "argument_summary": "The Committee on Geology and Subsoil Resources Management (the Geology Committee) is the organ of the Republic of Kazakhstan that controls and supervises subsoil use and is responsible for reviewing and approving projects for the exploration and development of oilfields.",
#     "party": "Respondent",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "Geology Committee",
#       "Committee on Geology and Subsoil Resources Management"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this definition of the Geology Committee."
#   },
#   {
#     "argument_summary": "The Western Kazakhstan Territorial Administration of Geology and Subsoil Use (TU Zapkaznedra) was the Geology Committee’s regional center that was competent with respect to CIOC.",
#     "party": "Respondent",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "TU Zapkaznedra",
#       "Western Kazakhstan Territorial Administration of Geology and Subsoil Use"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this definition of the TU Zapkaznedra."
#   },
#   {
#     "argument_summary": "JOR Investment Inc. SAL (JOR) is a Lebanese offshore company created in 2002 and held by Mr. Kassem Omar.",
#     "party": "Respondent",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "JOR",
#       "JOR Investment Inc. SAL",
#       "Kassem Omar"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this definition of JOR."
#   },
#   {
#     "argument_summary": "The Claimants are represented in this arbitration by Dr. Hamid G. Gharavi, Ms. Nada Sader and Mr. Sergey Alekhin.",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "Hamid G. Gharavi",
#       "Nada Sader",
#       "Sergey Alekhin"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this definition of the Claimants' legal representation."
#   },
#   {
#     "argument_summary": "The Respondent is represented in this arbitration by Mr. Peter M. Wolrich, Mr. Geoffroy Lyonnet, Ms. Gabriela Alvarez Avila, Mr. Jerome Lehucher, Ms. Svetlana Evliya, Ms. Anna Kouyate, Mr. Yerzhan Mukhitdinov, Ms. Marie-Claire Argac, Ms. Lisa Arpin-Pont and Ms. Olena Stasyk.",
#     "party": "Respondent",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "Peter M. Wolrich",
#       "Geoffroy Lyonnet",
#       "Jerome Lehucher",
#       "Marie-Claire Argac",
#       "Lisa Arpin-Pont",
#       "Olena Stasyk",
#       "Gabriela Alvarez Avila",
#       "Yerzhan Mukhitdinov"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this definition of the Respondent's legal representation."
#   },
#   {
#     "argument_summary": "The Contract No. 954 for the Exploration and Production of Hydrocarbons was entered into between CCC and the MEMR on 27 May 2002 and assigned to CIOC by means of Amendment No. 1 to the Contract dated 26 December 2002.",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "Contract No. 954",
#       "Exploration and Production of Hydrocarbons",
#       "CCC",
#       "MEMR",
#       "Amendment No. 1"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Contract."
#   },
#   {
#     "argument_summary": "The Claimants' Minimum Work Program (MWP) for the exploration period was attached as Appendix 6 to the Contract.",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "Minimum Work Program",
#       "MWP"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the MWP."
#   },
#   {
#     "argument_summary": "The MWP defined the essential works to be realized during the first five years and provided for a budget of USD 36,580,000.",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "MWP",
#       "budget"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the MWP."
#   },
#   {
#     "argument_summary": "The MWP was discussed between CIOC and TU Zapkaznedra every year by means of the Annual Work Program (AWP) to determine a more detailed work program and budget for the coming year and to reflect the reality on the ground both in terms of work and costs.",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "AWP",
#       "Annual Work Program",
#       "TU Zapkaznedra"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the AWP."
#   },
#   {
#     "argument_summary": "On 23 April 2007, CIOC and MEMR agreed and signed the minimum work program for the two-year extension period (the Revised Work Program or Extended MWP).",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "Revised Work Program",
#       "Extended MWP"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Revised Work Program."
#   },
#   {
#     "argument_summary": "The performance of the Contract by CIOC is a major point of contention between the Parties.",
#     "party": "Respondent",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "performance of the Contract",
#       "point of contention"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the performance of the Contract."
#   },
#   {
#     "argument_summary": "The Claimants submit that the Respondent was at all stages fully informed of CIOC’s performance and progress with respect to the Contract, and the supervision and monitoring by the Respondent of CIOC and the project were carried out by various organs and authorities of Kazakhstan.",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "performance",
#       "supervision",
#       "monitoring"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Claimants' position."
#   },
#   {
#     "argument_summary": "The Claimants allege that they spent more than five years to \"de-risk\" the \"Contract Area\", making it ready to produce oil on a commercial scale, investing over USD 39 million between December 2002 and March 2008, and a further USD 18 million during the two-year extension of the exploration period.",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "de-risk",
#       "Contract Area",
#       "investment"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Claimants' position."
#   },
#   {
#     "argument_summary": "The Respondent disagrees with the Claimants’ representation of CIOC’s performance of the Contract.",
#     "party": "Respondent",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "performance of the Contract"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Respondent's position."
#   },
#   {
#     "argument_summary": "The Respondent submits that, from the beginning, CIOC was only interested in taking advantage of the known supra-salt deposits and the existing Soviet wells to immediately produce oil for its own benefit, rather than to fulfill its contractual obligations and to carry out essential exploration works.",
#     "party": "Respondent",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "supra-salt deposits",
#       "exploration works"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Respondent's position."
#   },
#   {
#     "argument_summary": "In November 2006, Mr. Devincci Hourani, in his capacity as CIOC’s President, requested a two-year extension of the Contract’s exploration period.",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "Devincci Hourani",
#       "extension of the Contract"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Claimants' position."
#   },
#   {
#     "argument_summary": "On 20 January 2007, CIOC submitted a proposed minimum work program for the extension period (2007-2009).",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "work program",
#       "extension period"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Claimants' position."
#   },
#   {
#     "argument_summary": "On 16 February 2007, the MEMR approved the two-year extension of the exploration period, with the Revised Work Program, and notified this decision to CIOC on 21 February 2007.",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "MEMR",
#       "extension of the exploration period",
#       "Revised Work Program"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Claimants' position."
#   },
#   {
#     "argument_summary": "On 27 July 2007, Amendment No. 3 to the Contract, which provided for the extension of the exploration period until 27 May 2009, was entered into between CIOC and the MEMR.",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "Amendment No. 3",
#       "extension of the exploration period",
#       "MEMR"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Claimants' position."
#   },
#   {
#     "argument_summary": "On 7 September 2007, the Prosecutor’s Office of Aktobe Oblast sent to the MEMR a \"Recommendation on elimination for disregard of the rule of law\".",
#     "party": "Respondent",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "Prosecutor’s Office",
#       "Recommendation on elimination for disregard of the rule of law"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Respondent's position."
#   },
#   {
#     "argument_summary": "On 1 October 2007, the MEMR notified to CIOC a \"Notice of Termination of Operations\".",
#     "party": "Respondent",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "MEMR",
#       "Notice of Termination of Operations"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Respondent's position."
#   },
#   {
#     "argument_summary": "On 30 January 2008, the MEMR issued an Ordinance, ordering to \"[t]erminate Contract No. 954 of 27 May 2002, signed with Caratube International Oil Company LLP […] due to failure of completion of notice requirements within the specified period\".",
#     "party": "Respondent",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "MEMR",
#       "Ordinance",
#       "termination of Contract"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Respondent's position."
#   },
#   {
#     "argument_summary": "On 5 June 2013, the Claimants submitted their Request for Arbitration, requesting the institution of arbitration proceedings against the Respondent.",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "Request for Arbitration"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Claimants' position."
#   },
#   {
#     "argument_summary": "The Claimants submit that the merits of their case are governed by international law and/or the Contract, and alternatively by Kazakh law, regardless of the legal basis of this Tribunal’s jurisdiction.",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "merits",
#       "international law",
#       "Contract",
#       "Kazakh law"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Claimants' position."
#   },
#   {
#     "argument_summary": "The Claimants submit that customary international law with respect to the treatment of foreign investors and their investments must apply.",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "customary international law",
#       "treatment of foreign investors"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Claimants' position."
#   },
#   {
#     "argument_summary": "The Claimants submit that the applicable international law rules include the duty to provide fair and equitable treatment and full protection and security, as well as protection against arbitrary measures and expropriation save for a public purpose and subject to effective, prompt and adequate compensation, and compliance with the principle of proportionality.",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "fair and equitable treatment",
#       "full protection and security",
#       "expropriation",
#       "proportionality"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Claimants' position."
#   },
#   {
#     "argument_summary": "For the Claimants, the substantive provisions of the FIL apply whether or not jurisdiction is based thereon or on the Contract, because the Contract provides expressly for the application of the FIL.",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "FIL",
#       "Foreign Investment Law"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Claimants' position."
#   },
#   {
#     "argument_summary": "For the Claimants, the applicable substantive provisions of the FIL include (i) the stability clause in Article 6(1) FIL which, in the present case, stabilizes the investors’ investment position for the entire contractual term, namely for at least 32 years; (ii) Article 7 FIL, which protects the Claimants against nationalization, expropriation or any other measure having the same effects on foreign investments without \"due process of law\", \"without discrimination\", and \"in the payment of immediate, adequate and effective compensation\"; (iii) Article 8 FIL, which protects the Claimants against unlawful actions of State bodies and officials; and (iv) Article 9 FIL, which, in combination with Article 7 FIL, provides for a guarantee for compensation in case of expropriation for \"losses caused by illegal suspension, restriction or termination of the business activities of a foreign investor\".",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "FIL",
#       "stability clause",
#       "expropriation",
#       "compensation"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Claimants' position."
#   },
#   {
#     "argument_summary": "The Claimants submit that the FIL’s Most-Favored Nation clause (MFN) in Article 4(1) FIL is also applicable. It extends to the Claimants’ investments and triggers the application of further rights by virtue of the Respondent’s obligations under other international legal instruments, including the obligation (i) to ensure fair and equitable treatment; (ii) to ensure full protection and security to the Claimants’ investments; (iii) to afford the Claimants’ investments a treatment no less than that required by international law; and (iv) to protect against expropriation, except in certain situations and under certain conditions.",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "MFN",
#       "Most-Favored Nation clause",
#       "fair and equitable treatment",
#       "expropriation"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Claimants' position."
#   },
#   {
#     "argument_summary": "The Claimants argue that the Contract may be relied upon regardless of whether the Tribunal will ultimately accept its jurisdiction under the FIL or the Contract, because the FIL imposes, indirectly through the MFN clause, on the Respondent the obligation to \"observe any obligations it may have entered into with regard to [the Claimants’] investments\".",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "Contract",
#       "FIL",
#       "MFN clause"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Claimants' position."
#   },
#   {
#     "argument_summary": "For the Claimants, a number of Kazahk legislative acts are also relevant to the dispute at hand, including the Kazakh Constitution, the Kazakh Civil Code, the Law on Subsoil, and the Law on Oil.",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "Kazakh Constitution",
#       "Kazakh Civil Code",
#       "Law on Subsoil",
#       "Law on Oil"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Claimants' position."
#   },
#   {
#     "argument_summary": "For the Claimants, the applicable version of the Subsoil Law is the one applicable at the time of the signature of the Contract, namely the Subsoil Law as amended in 1999 (the 1999 Subsoil Law).",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "1999 Subsoil Law",
#       "Subsoil Law"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Claimants' position."
#   },
#   {
#     "argument_summary": "For the Claimants, the 1999 Subsoil Law provides very limited grounds for the termination of the Contract, including failure to commence contractual performance on time and substandard production levels. By contrast, the 2004 Subsoil Law, on which the Respondent relies, provides for a \"sweeping right to terminate subsoil contracts following any violation, upon failure to conform to notice, granting a reasonable time to cure\".",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "1999 Subsoil Law",
#       "2004 Subsoil Law",
#       "termination of the Contract"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Claimants' position."
#   },
#   {
#     "argument_summary": "For the Claimants, the 1999 Subsoil Law provides for separate procedures for the case of the suspension of a contract, on the one hand, and its unilateral termination by the Competent Authority, i.e. the MEMR, on the other hand.",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "1999 Subsoil Law",
#       "suspension of a contract",
#       "unilateral termination"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Claimants' position."
#   },
#   {
#     "argument_summary": "For the Claimants, only if the subsoil user fails to comply with the written notice pursuant to Article 70 of the 1999 Subsoil Law \"within the established period\", can the MEMR terminate the Contract under Article 45(2) of the 1999 Subsoil Law.",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "1999 Subsoil Law",
#       "MEMR",
#       "termination of the Contract"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Claimants' position."
#   },
#   {
#     "argument_summary": "To determine the meaning of the term \"substantial violation\" (which the Claimants read as \"material breach\"), the Claimants rely on Article 401 of the Kazakh Civil Code, according to which \"a violation of the agreement by one of the parties shall be deemed material if it entails for the other party such damage that it to a substantial degree loses something on which it had the right to count when concluding the agreement\".",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "substantial violation",
#       "material breach",
#       "Kazakh Civil Code"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Claimants' position."
#   },
#   {
#     "argument_summary": "For the Claimants, Kazakh scholars generally do not approve of the practice of unilateral termination of contracts by the State, considering it to violate the principle of equality of parties in civil-law relations.",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "unilateral termination of contracts",
#       "principle of equality"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Claimants' position."
#   },
#   {
#     "argument_summary": "The Claimants submit that the Kazakh Law on Oil of 28 June 1995 (Law on Oil) is also applicable, in particular Article 29 which regulates the modification and termination of oil contracts.",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "Law on Oil",
#       "modification",
#       "termination of oil contracts"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Claimants' position."
#   },
#   {
#     "argument_summary": "The Claimants refer to the substantive and procedural safeguards provided in the 2006 Kazakh Law on Private Entrepreneurship.",
#     "party": "Claimant",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "2006 Kazakh Law on Private Entrepreneurship"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Claimants' position."
#   },
#   {
#     "argument_summary": "According to the Respondent, the law governing the merits of the Claimants’ claims depends on the Tribunal’s jurisdictional basis.",
#     "party": "Respondent",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "merits",
#       "jurisdictional basis"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Respondent's position."
#   },
#   {
#     "argument_summary": "The Respondent argues that the Claimants cannot assert rights under Kazakh law, international law and the Contract regardless of the Tribunal’s jurisdictional basis.",
#     "party": "Respondent",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "Kazakh law",
#       "international law",
#       "Contract"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Respondent's position."
#   },
#   {
#     "argument_summary": "The Respondent contends that the only rights at issue in this case are CIOC’s rights under the Contract and rights arising from general principles of Kazakh law.",
#     "party": "Respondent",
#     "legal_basis": "N/A",
#     "key_keywords": [
#       "Contract",
#       "Kazakh law"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal accepted this description of the Respondent's position."
#   },
#   {
#     "argument_summary": "The Tribunal finds that it must apply Kazakh law to resolve disputes arising under the Contract.",
#     "party": "Tribunal",
#     "legal_basis": "Article 42(1) of the ICSID Convention, Clause 26.1 of the Contract",
#     "key_keywords": [
#       "Kazakh law",
#       "Contract"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal found that it must apply Kazakh law to resolve disputes arising under the Contract."
#   },
#   {
#     "argument_summary": "The Tribunal finds that it can take into consideration international law, namely customary international law, on the basis of Article 42(1) of the ICSID Convention.",
#     "party": "Tribunal",
#     "legal_basis": "Article 42(1) of the ICSID Convention",
#     "key_keywords": [
#       "customary international law",
#       "Article 42(1) of the ICSID Convention"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal found that it can take into consideration international law."
#   },
#   {
# ...
#     "key_keywords": [
#       "fair and equitable treatment",
#       "SPR",
#       "80/80 Regulation",
#       "arbitrariness",
#       "legitimate expectations"
#     ],
#     "court_followed": "No",
#     "tribunal_reasoning": "The Tribunal concluded that the Respondent did not breach Article 3(2) of the BIT."
#   },
#   {
#     "argument_summary": "The Claimants argued that the Respondent's actions in enacting the SPR and 80/80 Regulation violated Article 5 of the BIT.",
#     "party": "Claimant",
#     "legal_basis": "BIT Art. 5",
#     "key_keywords": [
#       "expropriation",
#       "SPR",
#       "80/80 Regulation",
#       "brand assets",
#       "intellectual property"
#     ],
#     "court_followed": "No",
#     "tribunal_reasoning": "The Tribunal concluded that the Challenged Measures were a valid exercise by Uruguay of its police powers for the protection of public health. As such, they cannot constitute an expropriation of the Claimants' investment."
#   },
#   {
#     "argument_summary": "The Claimants argued that the Respondent's actions in enacting the SPR and 80/80 Regulation violated Article 11 of the BIT.",
#     "party": "Claimant",
#     "legal_basis": "BIT Art. 11",
#     "key_keywords": [
#       "observance of commitments",
#       "SPR",
#       "80/80 Regulation",
#       "trademarks",
#       "right to use"
#     ],
#     "court_followed": "No",
#     "tribunal_reasoning": "The Tribunal concluded that trademarks are not \"commitments\" falling within the intended scope of Article 11 of the BIT. Accordingly, the Claimants' claim of breach by the Respondent of Article 11 by the adoption of the Challenged Measures is rejected."
#   },
#   {
#     "argument_summary": "The Claimants argued that the TCA's decision on the SPR amounted to a denial of justice because the TCA failed to address Abal's arguments and evidence and instead considered the challenge against the same regulation brought by one of its competitors, British American Tobacco.",
#     "party": "Claimant",
#     "legal_basis": "BIT Art. 3(2), *Mondev v. United States* (RLA-117), *Roberts* (CLA-241), *Chattin* (CLA-242)",
#     "key_keywords": [
#       "denial of justice",
#       "TCA decision",
#       "SPR",
#       "procedural fairness",
#       "due process"
#     ],
#     "court_followed": "No",
#     "tribunal_reasoning": "The Tribunal holds that the procedural improprieties were not sufficient in this case to rise to the standard of a denial of justice and decides that there was no denial of justice also in the SPR proceedings."
#   },
#   {
#     "argument_summary": "The Claimants argued that the final decision of Uruguay's Supreme Court of Justice ("SCJ") on the constitutionality of Law 18,256 (Article 9) and the TCA's Decision on the legality and validity of the 80/80 Regulation were directly contradictory with no way to reconcile that contradiction without incurring in a denial of justice.",
#     "party": "Claimant",
#     "legal_basis": "BIT Art. 3(2)",
#     "key_keywords": [
#       "denial of justice",
#       "SCJ decision",
#       "TCA decision",
#       "80/80 Regulation",
#       "contradictory decisions"
#     ],
#     "court_followed": "No",
#     "tribunal_reasoning": "The Tribunal holds that the procedural improprieties were not sufficient in this case to rise to the standard of a denial of justice and decides that there was no denial of justice also in the SPR proceedings."
#   },
#   {
#     "argument_summary": "The Respondent argued that the SPR and 80/80 Regulation were legitimate exercises of the State's sovereign police power to protect public health.",
#     "party": "Respondent",
#     "legal_basis": "Customary International Law, VCLT Art. 31, BIT Art. 2(1), *Chemtura* (RLA-53), *Too v. Greater Modesto* (RLA-153), *Bischoff* (RLA-138)",
#     "key_keywords": [
#       "police power",
#       "public health",
#       "sovereign power",
#       "SPR",
#       "80/80 Regulation"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal agreed that the Challenged Measures were a valid exercise by Uruguay of its police powers for the protection of public health."
#   },
#   {
#     "argument_summary": "The Respondent argued that the Claimants' expropriation claim fails because the measures did not render the business virtually without value.",
#     "party": "Respondent",
#     "legal_basis": "BIT Art. 5(1), *Feldman* (RLA-201), *Pope & Talbot* (RLA-216), *Glamis* (RLA-183), *Archer Daniels* (RLA-178), *LG&E* (RLA-65), *CMS* (CLA-093), *Encana*",
#     "key_keywords": [
#       "indirect expropriation",
#       "substantial deprivation",
#       "business value",
#       "SPR",
#       "80/80 Regulation"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal found that the effects of the SPR were far from depriving Abal of the value of its business or even causing a \"substantial deprivation\" of the value, use or enjoyment of the Claimants' investments."
#   },
#   {
#     "argument_summary": "The Respondent argued that the Claimants had no trademark rights capable of being expropriated because the variants were not registered.",
#     "party": "Respondent",
#     "legal_basis": "Uruguayan Trademark Law, Paris Convention Art. 5(C)(2), DNPI Resolution No. 21/2001 (R-375)",
#     "key_keywords": [
#       "trademark ownership",
#       "registration",
#       "Uruguayan Trademark Law",
#       "SPR",
#       "80/80 Regulation"
#     ],
#     "court_followed": "Partial/Deferred",
#     "tribunal_reasoning": "The Tribunal assumed, without deciding, that the trademarks continued to be protected under the Uruguay Trademark Law."
#   },
#   {
#     "argument_summary": "The Respondent argued that Uruguayan law confers trademark registrants only a right to protect against use by others, not a right to use.",
#     "party": "Respondent",
#     "legal_basis": "Uruguayan Trademark Law, MERCOSUR Protocol, Paris Convention, TRIPS Agreement, Montevideo Treaty",
#     "key_keywords": [
#       "right to use",
#       "trademark",
#       "Uruguayan law",
#       "exclusive right",
#       "right to exclude"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal concluded that under Uruguayan law or international conventions to which Uruguay is a party the trademark holder does not enjoy an absolute right of use, free of regulation, but only an exclusive right to exclude third parties from the market so that only the trademark holder has the possibility to use the trademark in commerce, subject to the State's regulatory power."
#   },
#   {
#     "argument_summary": "The Respondent argued that the Challenged Measures were not arbitrary because they were adopted in good faith and in a non-discriminatory manner to protect public health.",
#     "party": "Respondent",
#     "legal_basis": "RCM, ¶ 8.16, RR, ¶¶ 7.18-7.23, *ELSI* (CLA-088), *El Paso* (CLA-102), *Noble Ventures* (RLA-165), *Genin* (RLA-157)",
#     "key_keywords": [
#       "arbitrary",
#       "good faith",
#       "non-discriminatory",
#       "public health",
#       "Challenged Measures"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal found that the Challenged Measures were not arbitrary."
#   },
#   {
#     "argument_summary": "The Respondent argued that the Claimants' legitimate expectations were not violated because they were not based on specific commitments.",
#     "party": "Respondent",
#     "legal_basis": "RCM, ¶ 8.31-34; RR, ¶¶ 7.44, 7.48, 7.51-7.54, *Glamis* (RLA-183), *Duke Energy* (CLA-98; CLA-228), *EDF* (CLA-224), *GEA Group Aktiengesellschaft v. Ukraine* (RLA-191), *Ulysseas, Inc. v. Republic of Ecuador,* (RLA-196)",
#     "key_keywords": [
#       "legitimate expectations",
#       "specific commitments",
#       "general legislation",
#       "Uruguayan trademark law",
#       "Challenged Measures"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal concluded that the Claimants had no legitimate expectations that such or similar measures would not be adopted and further considering that their effect had not been such as to modify the stability of the Uruguayan legal framework."
#   },
#   {
#     "argument_summary": "The Respondent argued that the Claimants' FET claim should be barred under the principle of ex dolo malo non oritur actio (a right of action cannot be raised out of fraud) or the \"unclean hands doctrine.\"",
#     "party": "Respondent",
#     "legal_basis": "RR, ¶ 7.32",
#     "key_keywords": [
#       "unclean hands",
#       "fraud",
#       "deceit",
#       "ex dolo malo non oritur actio",
#       "industry deception"
#     ],
#     "court_followed": "Partial/Deferred",
#     "tribunal_reasoning": "The Tribunal's conclusion regarding the dismissal of the Claimants' claim of breach of Article 3(2) means that the Tribunal has no need to examine the Respondent's objection that the Claimants are prevented from bringing a FET claim due to their alleged fraudulent behavior."
#   },
#   {
#     "argument_summary": "The Respondent argued that the TCA's decision on the SPR was not a denial of justice because the TCA addressed Abal's arguments and the opinions of its experts, and rendered a well-reasoned decision.",
#     "party": "Respondent",
#     "legal_basis": "RCM, ¶ 11.6, RR, ¶¶ 11.20-11.37",
#     "key_keywords": [
#       "denial of justice",
#       "TCA decision",
#       "SPR",
#       "procedural fairness",
#       "due process"
#     ],
#     "court_followed": "Yes",
#     "tribunal_reasoning": "The Tribunal holds that the procedural improprieties were not sufficient in this case to rise to the standard of a denial of justice and decides that there was no denial of justice also in the SPR proceedings."
#   }
# ]
# ```
#   - Analyzing: 'Concurring and Dissenting Opinion of Gary Born' (Concurring and dissenting opinion)
#   - Analyzing: 'Decision on Rectification' (Supplementary)
#
# Processing complete. Creating DataFrame from extracted arguments.
#
# Database created successfully with 4824 arguments.
# Saved to 'legal_arguments_database.csv'
#    case_identifier                         case_title  \
# 0                      Bacilio Amorrortu v. Peru (II)
# 1                      Bacilio Amorrortu v. Peru (II)
# 2                      Bacilio Amorrortu v. Peru (II)
# 3                      Bacilio Amorrortu v. Peru (II)
# 4                      Bacilio Amorrortu v. Peru (II)
# 5                      Bacilio Amorrortu v. Peru (II)
# 6                      Bacilio Amorrortu v. Peru (II)
# 7                      Bacilio Amorrortu v. Peru (II)
# 8                      Bacilio Amorrortu v. Peru (II)
# 9                      Bacilio Amorrortu v. Peru (II)
# 10         IDS-796  Itisaluna Iraq and others v. Iraq
# 11         IDS-796  Itisaluna Iraq and others v. Iraq
# 12         IDS-796  Itisaluna Iraq and others v. Iraq
# 13         IDS-796  Itisaluna Iraq and others v. Iraq
# 14         IDS-796  Itisaluna Iraq and others v. Iraq
#
#                                       document_title  document_type  \
# 0   Procedural Order No. 2 (Decision on Bifurcation)    Bifurcation
# 1   Procedural Order No. 2 (Decision on Bifurcation)    Bifurcation
# 2   Procedural Order No. 2 (Decision on Bifurcation)    Bifurcation
# 3   Procedural Order No. 2 (Decision on Bifurcation)    Bifurcation
# 4   Procedural Order No. 2 (Decision on Bifurcation)    Bifurcation
# 5   Procedural Order No. 2 (Decision on Bifurcation)    Bifurcation
# 6   Procedural Order No. 2 (Decision on Bifurcation)    Bifurcation
# 7   Procedural Order No. 2 (Decision on Bifurcation)    Bifurcation
# 8   Procedural Order No. 2 (Decision on Bifurcation)    Bifurcation
# 9   Procedural Order No. 2 (Decision on Bifurcation)    Bifurcation
# 10                                             Award  Award (Final)
# 11                                             Award  Award (Final)
# 12                                             Award  Award (Final)
# 13                                             Award  Award (Final)
# 14                                             Award  Award (Final)
#
#          party                                   argument_summary  \
# 0     Claimant  The Claimant argues that the Respondent's obje...
# 1     Claimant  The Claimant argues that the Respondent's obje...
# 2     Claimant  The Claimant argues that the time-bar objectio...
# 3     Claimant  The Claimant argues that the consultation and ...
# 4     Claimant  The Claimant argues that the notice of intent ...
# 5   Respondent  The Respondent argues that the Claimant's clai...
# 6   Respondent  The Respondent argues that the Claimant failed...
# 7   Respondent  The Respondent argues that the Claimant failed...
# 8   Respondent  The Respondent argues that the Tribunal should...
# 9   Respondent  The Respondent argues that, in the alternative...
# 10    Claimant  The Claimants argued that the Tribunal has jur...
# 11    Claimant  The Claimants argued, in the alternative, that...
# 12  Respondent  The Respondent argued that the Tribunal lacks ...
# 13  Respondent  The Respondent argued that Article 17 of the O...
# 14  Respondent  The Respondent argued that Article 17 of the O...
#
#                                           legal_basis  \
# 0                                 USPTPA Art. 10.20.4
# 1         UNCITRAL Rules Art. 23(3), Glamis Gold test
# 2                                 USPTPA Art. 10.18.1
# 3                USPTPA Art. 10.15, USPTPA Art. 10.16
# 4                                 USPTPA Art. 10.16.2
# 5                                 USPTPA Art. 10.18.1
# 6                USPTPA Art. 10.15, USPTPA Art. 10.16
# 7                                 USPTPA Art. 10.16.2
# 8                                 USPTPA Art. 10.20.4
# 9         UNCITRAL Rules Art. 23(3), Glamis Gold test
# 10  OIC Agreement Arts. 8, 17, Iraq-Japan BIT Art....
# 11  OIC Agreement Art. 8, Iraq-Japan BIT Art. 17(4...
# 12  OIC Agreement Art. 17, ICSID Convention Art. 2...
# 13                              OIC Agreement Art. 17
# 14                              OIC Agreement Art. 17
#
#                                          key_keywords    court_followed  \
# 0   [bifurcation, jurisdictional objections, Artic...               Yes
# 1   [bifurcation, UNCITRAL Rules, Glamis Gold, fri...               Yes
# 2   [time-bar, limitation period, knowledge of bre...               Yes
# 3   [consultation and negotiation, pre-arbitral re...               Yes
# 4   [notice of intent, pre-arbitral requirements, ...               Yes
# 5   [time-bar, limitation period, knowledge of bre...                No
# 6   [consultation and negotiation, pre-arbitral re...                No
# 7   [notice of intent, pre-arbitral requirements, ...                No
# 8   [bifurcation, jurisdictional objections, Artic...                No
# 9   [bifurcation, UNCITRAL Rules, Glamis Gold, sub...                No
# 10  [MFN clause, ICSID jurisdiction, OIC Agreement...                No
# 11  [MFN clause, ICSID jurisdiction, OIC Agreement...                No
# 12  [ICSID jurisdiction, OIC Agreement, consent to...               Yes
# 13  [OIC Agreement, Article 17, consent to arbitra...  Partial/Deferred
# 14  [OIC Agreement, Article 17, investor-State arb...  Partial/Deferred
#
#                                    tribunal_reasoning
# 0   The Tribunal agreed that the objections were n...
# 1   The Tribunal agreed that bifurcation was not w...
# 2   The Tribunal agreed that the time-bar objectio...
# 3   The Tribunal agreed that the analysis required...
# 4   The Tribunal agreed that adjudicating Objectio...
# 5   The Tribunal found that the time-bar objection...
# 6   The Tribunal found that the analysis required ...
# 7   The Tribunal found that adjudicating Objection...
# 8   The Tribunal determined that the objections we...
# 9   The Tribunal agreed that bifurcation was not w...
# 10  The Tribunal found that the MFN clause in the ...
# 11  The Tribunal did not explicitly address this a...
# 12  The Tribunal agreed with the Respondent's argu...
# 13  The Tribunal found that resort to conciliation...
# 14  The Tribunal found that Article 17 contemplate...

# %%
# ==============================================================================
# STRATEGY ANALYSIS SCRIPT (WITH SOURCE TEXT HIGHLIGHTING)
# ==============================================================================
import vertexai
from vertexai.generative_models import GenerativeModel, GenerationConfig, HarmCategory, HarmBlockThreshold
import json

# --- Configuration & Initialization for Vertex AI ---
PROJECT_ID = "hack-thelaw25cam-586"
LOCATION = "us-central1"
vertexai.init(project=PROJECT_ID, location=LOCATION)

# --- Model Configuration for Reasoning Task ---
generation_config = GenerationConfig(
    temperature=0.3,
    top_p=0.95,
    top_k=40,
    max_output_tokens=8192,
)

safety_settings = {
    HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
}

# --- Using the user-specified model ---
# NOTE: "gemini-2.0-flash-lite-001" is not a standard public model.
# If this causes a "model not found" error, please change it to "gemini-1.5-pro-001".
MODEL_NAME = "gemini-2.0-flash-lite-001"
try:
    reasoning_model = GenerativeModel(
        MODEL_NAME,
        generation_config=generation_config,
        safety_settings=safety_settings
    )
    print(f"Vertex AI Initialized. Using user-specified model: '{MODEL_NAME}'.")
except Exception as e:
    print(f"ERROR: Could not initialize model '{MODEL_NAME}'. This model name may not be valid or accessible to your project.")
    print(f"Please use a standard model like 'gemini-1.5-pro-001'. Original error: {e}")
    raise


# ==============================================================================
# SELF-CONTAINED FUNCTION TO ANALYZE ARBITRATION STRATEGY
# ==============================================================================

def analyze_arbitration_strategy(strategy_text: str) -> str:
    """
    Takes a user's arbitration strategy, decomposes it into individual arguments, adds a title,
    classifies each argument, and highlights the source text for each argument.
    """
    if not strategy_text or not strategy_text.strip():
        return json.dumps({"error": "Strategy text cannot be empty"}, indent=4)

    # --- UPDATED PROMPT: Added 'source_text' requirement ---
    prompt = [
        "You are an expert legal counsel in international investment arbitration. Your task is to analyze the following proposed case strategy and break it down into its core, distinct legal arguments.",
        "For each distinct argument you identify, you must provide:",
        "1. `title`: A very short, 3-4 word title for the argument (e.g., 'Statute of Limitations Bar').",
        "2. `argument`: Formulate the argument as a concise, standalone statement.",
        "3. `category`: Classify the argument into one of three categories: 'Jurisdiction', 'Admissibility', or 'Merits'.",
        "4. `source_text`: Quote *verbatim* the exact sentence or sentences from the original input text that directly form the basis for this argument.",

        "Provide your output as a valid JSON array of objects. Do not include any other text, explanation, or markdown formatting. Each object must have these exact keys: `title`, `argument`, `category`, and `source_text`.",
        "Example output format:",
        """
[
  {
    "title": "Time-Barred Claim",
    "argument": "The claim is inadmissible because it was filed more than three years after the claimant knew about the alleged damages, exceeding the treaty's statute of limitations.",
    "category": "Admissibility",
    "source_text": "The claimant clearly knew about the alleged damages for over five years before filing, which is well past the three-year time limit specified in the treaty's dispute resolution clause."
  }
]
        """,
        "Here is the strategy text to analyze:",
        "---",
        strategy_text
    ]

    try:
        response = reasoning_model.generate_content(prompt)
        text_response = response.text
        # Robustly find and extract the JSON array from the model's response
        start = text_response.find('[')
        end = text_response.rfind(']')
        
        if start != -1 and end != -1:
            json_str = text_response[start:end+1]
            parsed_json = json.loads(json_str)
            return json.dumps(parsed_json, indent=4)
        else:
            return json.dumps({"error": "Could not find a valid JSON array in the model's response.", "raw_response": text_response}, indent=4)
            
    except json.JSONDecodeError as e:
        return json.dumps({"error": f"Failed to decode JSON after cleaning: {e}", "raw_response": response.text}, indent=4)
    except Exception as e:
        return json.dumps({"error": f"An unexpected error occurred: {str(e)}"}, indent=4)


# ==============================================================================
# EXAMPLE USAGE
# ==============================================================================

# --- Define a sample claimant's strategy ---
user_strategy = """
Our primary strategy is to first challenge the tribunal's jurisdiction. We will argue that the claimant's company, while incorporated locally, is ultimately owned by nationals of the host state, so there's no real foreign investment to protect. 
If that fails, we will argue that the claim itself is inadmissible. The claimant clearly knew about the alleged damages for over five years before filing, which is well past the three-year time limit specified in the treaty's dispute resolution clause.
Finally, on the substance of the case, we will demonstrate that the government's actions were legitimate, non-discriminatory regulatory measures designed to protect public health and did not amount to an expropriation of the claimant's investment. We will also contest their damages model, showing it's based on overly optimistic and speculative future profits.
"""

# --- Execute the analysis ---
analyzed_strategy_json = analyze_arbitration_strategy(user_strategy)

# --- Save the JSON string to a file ---
output_filename = "input_arguments.json"
with open(output_filename, 'w', encoding='utf-8') as f:
    f.write(analyzed_strategy_json)

print(f"Strategy analysis complete. Results saved to '{output_filename}'")

# --- Print the JSON to the console for immediate viewing ---
print("\n--- Decomposed Strategy with Source Highlighting ---")
print(analyzed_strategy_json)
# Out:
# Vertex AI Initialized. Using user-specified model: 'gemini-2.0-flash-lite-001'.
# Strategy analysis complete. Results saved to 'input_arguments.json'
#
# --- Decomposed Strategy with Source Highlighting ---
# [
#     {
#         "title": "No Foreign Investment",
#         "argument": "The tribunal lacks jurisdiction because the claimant company is ultimately owned by nationals of the host state, thus there is no foreign investment.",
#         "category": "Jurisdiction",
#         "source_text": "We will argue that the claimant's company, while incorporated locally, is ultimately owned by nationals of the host state, so there's no real foreign investment to protect."
#     },
#     {
#         "title": "Time-Barred Claim",
#         "argument": "The claim is inadmissible because it was filed more than three years after the claimant knew about the alleged damages, exceeding the treaty's statute of limitations.",
#         "category": "Admissibility",
#         "source_text": "The claimant clearly knew about the alleged damages for over five years before filing, which is well past the three-year time limit specified in the treaty's dispute resolution clause."
#     },
#     {
#         "title": "Legitimate Regulatory Action",
#         "argument": "The government's actions were legitimate, non-discriminatory regulatory measures designed to protect public health and did not constitute an expropriation.",
#         "category": "Merits",
#         "source_text": "Finally, on the substance of the case, we will demonstrate that the government's actions were legitimate, non-discriminatory regulatory measures designed to protect public health and did not amount to an expropriation of the claimant's investment."
#     },
#     {
#         "title": "Flawed Damages Model",
#         "argument": "The claimant's damages model is flawed because it is based on overly optimistic and speculative future profits.",
#         "category": "Merits",
#         "source_text": "We will also contest their damages model, showing it's based on overly optimistic and speculative future profits."
#     }
# ]

# %%
# ==============================================================================
# ADVANCED STRATEGY ANALYSIS SCRIPT
# (With Factual Verification and Argument Discovery)
# ==============================================================================
import vertexai
from vertexai.generative_models import GenerativeModel, GenerationConfig, HarmCategory, HarmBlockThreshold
import json

# --- Configuration & Initialization for Vertex AI ---
PROJECT_ID = "hack-thelaw25cam-586"
LOCATION = "us-central1"
vertexai.init(project=PROJECT_ID, location=LOCATION)

# --- Model Configuration ---
generation_config = GenerationConfig(
    temperature=0.4, # Slightly higher temperature for more creative discovery
    top_p=0.95,
    top_k=40,
    max_output_tokens=8192,
)

safety_settings = {
    HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
    HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
}

# --- Using the user-specified model ---
# NOTE: "gemini-2.0-flash-lite-001" is not a standard public model.
# If this causes a "model not found" error, switch to "gemini-1.5-pro-001" which is better for this task.
MODEL_NAME = "gemini-2.0-flash-lite-001"
try:
    reasoning_model = GenerativeModel(
        MODEL_NAME,
        generation_config=generation_config,
        safety_settings=safety_settings
    )
    print(f"Vertex AI Initialized. Using user-specified model: '{MODEL_NAME}'.")
except Exception as e:
    print(f"ERROR: Could not initialize model '{MODEL_NAME}'. This model name may not be valid or accessible to your project.")
    print(f"Please use a standard model like 'gemini-1.5-pro-001'. Original error: {e}")
    raise


# ==============================================================================
# SELF-CONTAINED FUNCTION TO ANALYZE ARBITRATION STRATEGY AGAINST FACTS
# ==============================================================================

def analyze_arbitration_strategy(strategy_text: str, factual_text: str) -> str:
    """
    Analyzes a legal strategy against a factual background to verify arguments,
    find contradictions, and discover new potential arguments.
    """
    if not strategy_text or not factual_text:
        return json.dumps({"error": "Both strategy_text and factual_text must be provided"}, indent=4)

    # --- UPDATED PROMPT: Incorporates factual check and argument discovery ---
    prompt = [
        "You are an expert legal counsel in international investment arbitration. You will be given two pieces of text: a 'CASE STRATEGY' and a 'FACTUAL BACKGROUND'.",
        "Your task is to perform a comprehensive analysis and produce a single JSON array containing all identified arguments. You must perform three steps:",
        "1. Deconstruct the user's 'CASE STRATEGY' into its core arguments.",
        "2. For each of those arguments, cross-reference it with the 'FACTUAL BACKGROUND' and your knowledge of international arbitration to check for accuracy. Be aware that arguments from the users strategy might be factually incorect",
        "3. Identify any NEW potential arguments (for or against the user's position) that are suggested by the 'FACTUAL BACKGROUND' but were NOT mentioned in the 'CASE STRATEGY'.",

        "For EACH argument in the final JSON output, you must provide:",
        " - `title`: A very short, 3-4 word title for the argument.",
        " - `argument`: A concise, standalone statement of the argument.",
        " - `category`: Classify as 'Jurisdiction', 'Admissibility', or 'Merits'.",
        " - `factual_check`: true if it is consistent with the factual background or provide a short correction (e.g., 'Correction: The contract specifies a 90-day notice period, not 60.'). Be aware that the user may need to be corrected",
        " - `source_text`: For arguments from the user's strategy, quote the verbatim source sentence(s). For newly discovered arguments, this should be 'N/A'.",
        " - `is_new_argument`: A boolean value. `false` for arguments from the user's strategy, `true` for newly discovered arguments.",

        "Provide your output as a single, valid JSON array of objects only. Do not add explanations outside the JSON.",
        "Example output format:",
        """
[
  {
    "title": "Legitimate Regulatory Action",
    "argument": "The government's actions were legitimate regulatory measures for public health and not expropriation.",
    "category": "Merits",
    "factual_check": "true",
    "source_text": "we will demonstrate that the government's actions were legitimate, non-discriminatory regulatory measures designed to protect public health and did not amount to an expropriation of the claimant's investment.",
    "is_new_argument": false
  },
  {
    "title": "New Fork-in-the-Road Argument",
    "argument": "The claimant may be barred from arbitration because they first initiated proceedings regarding the same dispute in the host state's local courts.",
    "category": "Admissibility",
    "factual_check": "true",
    "source_text": "N/A",
    "is_new_argument": true
  }
]
        """,
        "--- CASE STRATEGY ---",
        strategy_text,
        "--- FACTUAL BACKGROUND ---",
        factual_text
    ]

    try:
        response = reasoning_model.generate_content(prompt)
        text_response = response.text
        start = text_response.find('[')
        end = text_response.rfind(']')
        
        if start != -1 and end != -1:
            json_str = text_response[start:end+1]
            parsed_json = json.loads(json_str)
            return json.dumps(parsed_json, indent=4)
        else:
            return json.dumps({"error": "Could not find a valid JSON array in the model's response.", "raw_response": text_response}, indent=4)
            
    except json.JSONDecodeError as e:
        return json.dumps({"error": f"Failed to decode JSON after cleaning: {e}", "raw_response": response.text}, indent=4)
    except Exception as e:
        return json.dumps({"error": f"An unexpected error occurred: {str(e)}"}, indent=4)


# ==============================================================================
# EXAMPLE USAGE
# ==============================================================================

# --- 1. Define a sample case strategy ---
user_strategy = """
Our main line of attack will be on admissibility of the case for solar investment in spain. The claimant waited far too long to file this claim, well past the two-year prescription period mentioned in the treaty. We will also argue on the merits that our new tax law was a general measure that affected all companies equally and was not targeted at this foreign investor, so it cannot be a breach of FET. Also this is the wrong court they are addressing with this arbitration suit, they should have adressed the court for Kosovo.
"""

# --- 2. Define the supporting factual material ---
# This text will be used to verify the strategy and find new arguments.
factual_background = """
Excerpts from Bilateral Investment Treaty (BIT) Article 9: 'A claim must be submitted to arbitration within three (3) years from the date on which the claimant first acquired knowledge of the breach.'
Excerpts from BIT Article 11: 'This treaty's protections shall not apply if the investment was made through misrepresentation or concealment of material facts.'
Internal Memo dated 2018: 'The claimant's initial application for the investment license from 2015 appears to omit any mention of their prior environmental violations in their home country.'
"""

# --- 3. Execute the analysis ---
analyzed_strategy_json = analyze_arbitration_strategy(user_strategy, factual_background)

# --- 4. Save and Print the results ---
output_filename = "strategy_analysis_fact_checked.json"
with open(output_filename, 'w', encoding='utf-8') as f:
    f.write(analyzed_strategy_json)

print(f"Strategy analysis complete. Results saved to '{output_filename}'")

print("\n--- Fact-Checked & Augmented Strategy ---")
print(analyzed_strategy_json)
# Out:
# Vertex AI Initialized. Using user-specified model: 'gemini-2.0-flash-lite-001'.
# Strategy analysis complete. Results saved to 'strategy_analysis_fact_checked.json'
#
# --- Fact-Checked & Augmented Strategy ---
# [
#     {
#         "title": "Time-barred Claim",
#         "argument": "The claimant's claim is inadmissible because it was filed outside the three-year prescription period stipulated in the BIT.",
#         "category": "Admissibility",
#         "factual_check": "true",
#         "source_text": "The claimant waited far too long to file this claim, well past the two-year prescription period mentioned in the treaty.",
#         "is_new_argument": false
#     },
#     {
#         "title": "General Tax Measure",
#         "argument": "The new tax law was a general measure applied equally to all companies and did not specifically target the foreign investor, therefore it does not breach FET.",
#         "category": "Merits",
#         "factual_check": "true",
#         "source_text": "We will also argue on the merits that our new tax law was a general measure that affected all companies equally and was not targeted at this foreign investor, so it cannot be a breach of FET.",
#         "is_new_argument": false
#     },
#     {
#         "title": "Incorrect Jurisdiction",
#         "argument": "The arbitration is in the wrong forum; the claimant should have addressed the court for Kosovo.",
#         "category": "Jurisdiction",
#         "factual_check": "Correction: The provided factual background does not mention Kosovo or any specific court; this argument is unsupported.",
#         "source_text": "Also this is the wrong court they are addressing with this arbitration suit, they should have adressed the court for Kosovo.",
#         "is_new_argument": false
#     },
#     {
#         "title": "Misrepresentation in Investment",
#         "argument": "The investment is not protected by the BIT because the claimant misrepresented or concealed material facts, specifically their prior environmental violations.",
#         "category": "Admissibility",
#         "factual_check": "true",
#         "source_text": "N/A",
#         "is_new_argument": true
#     }
# ]
